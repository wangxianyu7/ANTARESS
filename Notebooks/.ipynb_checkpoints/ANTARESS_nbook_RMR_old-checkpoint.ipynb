# %% [markdown]
# # Running ANTARESS

# %% [markdown]
# Run this cell to run the ANTARESS workflow.

# %%
from antaress.ANTARESS_launch.ANTARESS_launcher import ANTARESS_launcher
ANTARESS_launcher(working_path=input_nbook['working_path'], nbook_dic = input_nbook, exec_comm=False)
# Out:
# ****************************************
# Launching ANTARESS
# ****************************************
#
# Multi-threading: 16 threads available
# Running with artificial data
# Covariances discounted
# Accounting for Keplerian motion from all planets
# Automatic definition of T14[Valinor]=2.62 h
# Default nsub_Dpl[Valinor]=49
#
# -----------------------
# Processing instrument : ESPRESSO
# -----------------------
#   Reading and initializing CCFs
#    > Data resampled on a common spectral table
#          Retrieving data
#            All exposures in 20230624 share a common spectral table
#    > 50 exposures
#   -----------------
#   Processing visit: 20230624
#   -----------------
#    > 50 exposures
#          22 in-transit
#          28 out-of-transit (14 pre / 14 post)
#    > Calculating properties of planet-occulted regions
#          Calculating data
#    > Analyzing disk-integrated stellar profiles
#          Calculating data
#          Systemic rv from time-series = -0.000901 +- 1.091092e-03 km/s
#    > Aligning disk-integrated profiles
#          Calculating data
#    > Broadband flux scaling
#          Default transit model
#          Calculating data
#    > Calculating master stellar spectrum
#          Calculating data
#    > Extracting residual profiles
#          Calculating data
#    > Extracting intrinsic stellar profiles
#          Calculating data
#    > Analyzing intrinsic stellar profiles
#          Retrieving data
# -------------------------------
# Processing combined instruments
# -------------------------------
#    > Fitting single stellar surface property
#      - Surface RVs
#        MCMC fit
#          Retrieving MCMC
#        -------------------------------
#        > Results
#          Parameter veq [km/s]
#            med : 2.889e+00
#            HDI    1s err : [-2.571e-01 +2.220e-01]
#                      int : [2.632e+00 ; 3.111e+00] (68.28 %)
#        -------------------------------
#          Parameter lambda_rad__plValinor [rad]
#            med : 4.648e-01
#            HDI    1s err : [-1.100e-01 +1.270e-01]
#                      int : [3.548e-01 ; 5.918e-01] (68.29 %)
#      - Intrinsic line contrast
#        MCMC fit
#          Retrieving MCMC
#        -------------------------------
#        > Results
#          Parameter ctrst_ord0__IS__VS_ []
#            med : 5.927e-01
#            HDI    1s err : [-3.413e-02 +3.605e-02]
#                      int : [5.585e-01 ; 6.287e-01] (68.35 %)
#      - Intrinsic line FWHM
#        MCMC fit
#          Retrieving MCMC
#        -------------------------------
#        > Results
#          Parameter FWHM_ord0__IS__VS_ [km/s]
#            med : 2.632e+00
#            HDI    1s err : [-1.962e-01 +1.884e-01]
#                      int : [2.436e+00 ; 2.820e+00] (68.32 %)
#      ----------------------------------
#    > Fitting joined intrinsic profiles
# Opt Level: -1
#        MCMC fit
#          Retrieving MCMC
#        -------------------------------
#        > Results
#          Parameter veq [km/s]
#            med : 2.913e+00
#            HDI    1s err : [-2.254e-01 +2.078e-01]
#                      int : [2.688e+00 ; 3.121e+00] (68.28 %)
#        -------------------------------
#          Parameter FWHM_ord0__IS__VS_ [km/s]
#            med : 2.518e+00
#            HDI    1s err : [-2.210e-01 +2.287e-01]
#                      int : [2.297e+00 ; 2.747e+00] (68.31 %)
#        -------------------------------
#          Parameter ctrst_ord0__IS__VS_ []
#            med : 6.582e-01
#            HDI    1s err : [-4.877e-02 +4.485e-02]
#                      int : [6.094e-01 ; 7.030e-01] (68.33 %)
#        -------------------------------
#          Parameter lambda_rad__plValinor [rad]
#            med : 4.770e-01
#            HDI    1s err : [-1.074e-01 +1.159e-01]
#                      int : [3.696e-01 ; 5.929e-01] (68.30 %)
#      ----------------------------------
#
# -----------------------------------
# Plots
# -----------------------------------
# Numerical T14[Valinor]=2.615818 h
# Numerical Kp_orb=143.77 km/s (Mstar = 1.171 Msun)
# -----------------------------------
# + Individual disk-integrated profiles
#    - Instrument : ESPRESSO
#      - Visit : 20230624
# -----------------------------------
# + Properties of raw data and disk-integrated profiles
#    ---------------
#    > RV
#      ESPRESSO
#       20230624
#    ---------------
#    > Contrast
#      ESPRESSO
#       20230624
#    ---------------
#    > FWHM
#      ESPRESSO
#       20230624
# -----------------------------------
# + 2D map: intrinsic stellar profiles
#    - Instrument : ESPRESSO
#      - Visit : 20230624
# -----------------------------------
# + Individual intrinsic profiles
#    - Instrument : ESPRESSO
#      - Visit : 20230624
# -----------------------------------
# + Properties of intrinsic stellar profiles
#    ---------------
#    > RV
#      ESPRESSO
#       20230624
#    ---------------
#    > Contrast
#      ESPRESSO
#       20230624
#    ---------------
#    > FWHM
#      ESPRESSO
#       20230624
# End of workflow

# %% [markdown]
# # Plot display

# %%
Image(filename = input_nbook['plot_path']+'DI_prop/rv_phase.png')

# %%
Image(filename = input_nbook['plot_path']+'DI_prop/ctrst_phase.png')

# %%
Image(filename = input_nbook['plot_path']+'DI_prop/FWHM_phase.png')
